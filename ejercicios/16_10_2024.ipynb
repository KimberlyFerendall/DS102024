# %% [markdown]
# 1. Escribir un programa que pregunte al usuario su edad y muestre por pantalla si es mayor de edad o no.

# %%
edad = int(input("¿Qué edad tienes?"))
if edad >= 18:
    print ("Eres mayor de edad")
else:
    print("Eres menor de edad")
# Out:
# Eres menor de edad

# %% [markdown]
# 2. Escribir un programa que pida al usuario un número entero y muestre por pantalla si es par o impar.

# %%
numero= int(input("Elija un número"))
if numero%2==0:
    print("Es par")
else:
    print("Es impar")
# Out:
# Es impar

# %%
def par_impar(numero:int)
    if numero//2==0:
        print("El número es par")
    else:
        print("El número es impar")
# Out:
#   Cell In[16], line 1
#     def par_impar(numero:int)
#                              ^
# SyntaxError: expected ':'

# %% [markdown]
# 3.
# ```
# *
# **
# ***
# ****
# *****

# %%
a= 'a aa aaa aaaa aaaaa'
a.replace("a","*")
a.replace(" ", "")
# Out:
# 'a\naa\naaa\naaaa\naaaaa'

# %%
n=5
for i in range(1, n+1):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
lista

for i in range(1,n+1)
print(*lista)
lista.append('*')

# %% [markdown]
# 4. Escribir un programa que pida al usuario una palabra y luego muestre por pantalla una a una las letras de la palabra introducida empezando por la última.

# %%
palabra = 'pokemon'
for letra in reversed(palabra):
    print(letra, end='')
# Out:
# nomekop

# %% [markdown]
# 5. Escribir un programa que almacene el abecedario en una lista, elimine de la lista las letras que ocupen posiciones múltiplos de 3, y muestre por pantalla la lista resultante.

# %%
import string

abc = string.ascii_lowercase

lista = []

for i in range(len(abc)):
    if i % 3 == 0:
        continue
    else:
        lista.append(abc[i])
print(lista)
# Out:
# ['b', 'c', 'e', 'f', 'h', 'i', 'k', 'l', 'n', 'o', 'q', 'r', 't', 'u', 'w', 'x', 'z']

# %% [markdown]
# 6. Escribir un programa que guarde en un diccionario los precios de las frutas de la tabla, pregunte al usuario por una fruta, un número de kilos y muestre por pantalla el precio de ese número de kilos de fruta. Si la fruta no está en el diccionario debe mostrar un mensaje informando de ello.

# %%
def calcular_precio(fruta:str, kilos:float)->float:
    dicc={
        'Manzana': 1.5,
        'Pera':2.0,
    }
input('¿Qué fruta quiere comprar?')
input('¿Cuánta fruta quiere comprar?')
def calcular_precios(dicc, fruta, kilos):
    if fruta.capitalize() in dicc.keys():
        return dicc[fruta]*kilos
    else:
        return'Fruta no encontrada en el diccionario'

print(calcular_precio('Manzana', 5))

# %% [markdown]
# 7. Escribir una función que reciba una muestra de números en una lista y devuelva su media y mediana.

# %%
numeros=[1,2,3,4,5,6]

punto_medio = len(numeros)//2

print(punto_medio)

numeros[punto_medio-1:punto_medio+1]

# %%
numeros = [1,2,3,4,5]
def media_mediana(lista:list)->float
media = sum(lista)/len(lista)
print(media)

lista.sort()
punto_medio=len(lista)//2

if len(lista) %2 != 0:
    mediana= lista[punto_medio]
else:
    mediana=sum(lista[punto_medio-1:punto_medio+1])

media_mediana(lista=numeros)

# %% [markdown]
# 8. Crear un programa que sin utilizar if-else si le pasas la variable XX te devuelva el pais. ejemplo: ES->España, us:Estados Unidos

# %%
def traducir_pais(codigo):

    dicc = {
    'es:España',
    'us: Estados Unidos',
    'fr: Francia'
}
    
    codigo = codigo.lower()

    return dicc.get(codigo,'no está act')

print(traducir_pais('es'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 13
#       9     codigo = codigo.lower()
#      11     return dicc.get(codigo,'no está act')
# ---> 13 print(traducir_pais('vz'))
#
# Cell In[8], line 11, in traducir_pais(codigo)
#       3     dicc = {
#       4     'es:España',
#       5     'us: Estados Unidos',
#       6     'fr: Francia'
#       7 }
#       9     codigo = codigo.lower()
# ---> 11     return dicc.get(codigo,'no está act')
#
# AttributeError: 'set' object has no attribute 'get'

# %% [markdown]
# 9. Nuria es fitness entonces tiene un itinerario para el gym:
#
# lunes = piernas
# martes = brazos
# miércoles = abdomen
# jueves = cardio
# viernes = cerveza
# sabado = pizza
# domingo = descansa
# vamos hacer un programa que dependiendo del dia nos diga que tenemos que hacer.
# pero resulta que Juan ahora es IFfobico y GETfobico..
# puedes ayudar a ambos??

# %%
def que_toca_hoy(dia):

    dicc={
        "lunes": "piernas", 
        "martes":"brazos",
        "miércoles":  "abdomen",
        "jueves": "cardio",
        "viernes": "cerveza",
        "sabado": "pizza",
        "domingo": "descansa"
      }
    
    try: 
        return dicc[dia]
    except KeyError:
        return 'Dia no válido'
que_toca_hoy('miércoles')
# Out:
# 'abdomen'

# %%
dia = 'lunes'
match dia:
    case 'lunes':
        print("piernas")
    case _:
        print ('no es un dia')
# Out:
# piernas
